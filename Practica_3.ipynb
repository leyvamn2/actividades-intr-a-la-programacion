# %%
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
import urllib.request
from PIL import Image

# %%
urlPicture="https://upload.wikimedia.org/wikipedia/commons/thumb/8/82/Circle-yellow.svg/1200px-Circle-yellow.svg.png"
internetPicture=Image.open(urllib.request.urlopen(urlPicture))
# la imagen se obtiene y se carga en una variable, después se convierte en matriz
yellowCircle=np.array(internetPicture)

# %%
plt.imshow(yellowCircle)

# %%
#nueva variable
faceTest=np.array(yellowCircle)
plt.figure(figsize=(10,20))
plt.imshow(faceTest)

# %%
#pintar ojo izquierdo, se interactua con las capas
faceTest[390:600,710:840,0]=0#cero=capa roja de RGB
faceTest[390:600,710:840,1]=0#cero=capa azul de RGB
faceTest[390:600,710:840,2]=0#cero=capa verde de RGB
faceTest[390:600,320:450,0]=0#cero=capa roja de RGB
faceTest[390:600,320:450,1]=0#cero=capa azul de RGB
faceTest[390:600,320:450,2]=0#cero=capa verde de RGB

#Boca abierta porque está sorprendida
faceTest[700:900,410:720,0]=0#cero=capa roja de RGB
faceTest[700:900,410:720,1]=0#cero=capa azul de RGB
faceTest[700:900,710:720,2]=0#cero=capa verde de RGB

#Sudor porque está nerviosa
faceTest[300:400,850:900,0]=173#cero=capa roja de RGB
faceTest[300:400,850:900,1]=216#cero=capa azul de RGB
faceTest[300:400,850:900,2]=230#cero=capa verde de RGB

#cejitaderecha


plt.figure(figsize=(10,20))
plt.imshow(faceTest)

# %% [markdown]
# Al final tenemos una carita asustada 😰 pero sin cejitas
